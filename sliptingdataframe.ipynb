# %%
import pandas as pd
import numpy as np
import os
import csv

# %%
full_df = pd.read_csv('tryouts.csv')

# %%
shotcut_df = full_df.drop(full_df[full_df.total_shots < 200].index)

# %%
shotcut_df["player"].nunique()
# Out:
# 344

# %%
shotcut_df['playername'] = shotcut_df['player']

# %%
shotcut_df.columns
# Out:
# Index(['period', 'team', 'team_uid', 'home_away', 'player', 'player_uid',
#        'points', 'result', 'total_shots', 'type', 'type_uid', 'shot_distance',
#        'converted_x', 'converted_y', 'playername'],
#       dtype='object')

# %%
shotcut_df.playername = shotcut_df.playername.str.replace(' ', '_')

# %%
dfs = dict(tuple(shotcut_df.groupby('playername')))

# %%
listdf = [dfs[x] for x in dfs]

# %%
print(listdf[10].player.unique())
# Out:
# ['Andre Drummond']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
i = 0
while i < len(dfs):
    y = listdf[i]['result']
    X = listdf[i][['period', 'team_uid', 'home_away', 'player_uid','total_shots', 'type_uid', 
             'shot_distance','converted_x', 'converted_y']]
#y = pd.get_dummies(y)

    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    y_trainArray = np.array(y_train).reshape(-1,1)


    X_scaler = StandardScaler().fit(X_train)
    y_scaler = StandardScaler().fit(y_trainArray)
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    train_scores = []
    test_scores = []
    knn = KNeighborsClassifier(n_neighbors=7)
    knn.fit(X_train_scaled, y_trainArray)
    train_score = knn.score(X_train_scaled, y_trainArray)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(listdf[i].player.unique())
    print(f"k: {7}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    i = i+1
# Out:
# C:\Users\pablo\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\pablo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ['Aaron Gordon']
# k: 7, Train/Test Score: 0.689/0.641
# ['Abdel Nader']
# k: 7, Train/Test Score: 0.684/0.615
# ['Al-Farouq Aminu']
# k: 7, Train/Test Score: 0.693/0.598
# ['Al Horford']
# k: 7, Train/Test Score: 0.700/0.604
# ['Al Jefferson']
# k: 7, Train/Test Score: 0.683/0.541
# ['Alec Burks']
# k: 7, Train/Test Score: 0.695/0.649
# ['Alex Abrines']
# k: 7, Train/Test Score: 0.691/0.578
# ['Alex Len']
# k: 7, Train/Test Score: 0.691/0.699
# ['Allen Crabbe']
# k: 7, Train/Test Score: 0.698/0.631
# ['Amir Johnson']
# k: 7, Train/Test Score: 0.736/0.548
# ['Andre Drummond']
# k: 7, Train/Test Score: 0.693/0.596
# ['Andre Iguodala']
# k: 7, Train/Test Score: 0.716/0.614
# ['Andre Roberson']
# k: 7, Train/Test Score: 0.740/0.580
# ['Andrew Harrison']
# k: 7, Train/Test Score: 0.732/0.680
# ['Andrew Wiggins']
# k: 7, Train/Test Score: 0.701/0.601
# ['Anthony Davis']
# k: 7, Train/Test Score: 0.747/0.678
# ['Anthony Tolliver']
# k: 7, Train/Test Score: 0.704/0.586
# ['Aron Baynes']
# k: 7, Train/Test Score: 0.666/0.513
# ['Austin Rivers']
# k: 7, Train/Test Score: 0.680/0.606
# ['Avery Bradley']
# k: 7, Train/Test Score: 0.692/0.559
# ['Bam Adebayo']
# k: 7, Train/Test Score: 0.703/0.650
# ['Ben McLemore']
# k: 7, Train/Test Score: 0.682/0.627
# ['Ben Simmons']
# k: 7, Train/Test Score: 0.669/0.611
# ['Bismack Biyombo']
# k: 7, Train/Test Score: 0.717/0.598
# ['Blake Griffin']
# k: 7, Train/Test Score: 0.722/0.614
# ['Boban Marjanovic']
# k: 7, Train/Test Score: 0.710/0.645
# ['Bobby Portis']
# k: 7, Train/Test Score: 0.700/0.583
# ['Bogdan Bogdanovic']
# k: 7, Train/Test Score: 0.699/0.601
# ['Bojan Bogdanovic']
# k: 7, Train/Test Score: 0.697/0.641
# ['Bradley Beal']
# k: 7, Train/Test Score: 0.689/0.603
# ['Brandon Ingram']
# k: 7, Train/Test Score: 0.689/0.521
# ['Brook Lopez']
# k: 7, Train/Test Score: 0.711/0.538
# ['Bryn Forbes']
# k: 7, Train/Test Score: 0.667/0.517
# ['Buddy Hield']
# k: 7, Train/Test Score: 0.670/0.492
# ['C.J. Williams']
# k: 7, Train/Test Score: 0.736/0.667
# ['CJ McCollum']
# k: 7, Train/Test Score: 0.691/0.557
# ['CJ Miles']
# k: 7, Train/Test Score: 0.706/0.592
# ['Cameron Payne']
# k: 7, Train/Test Score: 0.630/0.448
# ['Caris LeVert']
# k: 7, Train/Test Score: 0.687/0.519
# ['Carmelo Anthony']
# k: 7, Train/Test Score: 0.677/0.576
# ['Cedi Osman']
# k: 7, Train/Test Score: 0.732/0.422
# ['Chandler Parsons']
# k: 7, Train/Test Score: 0.646/0.530
# ['Channing Frye']
# k: 7, Train/Test Score: 0.740/0.603
# ['Cheick Diallo']
# k: 7, Train/Test Score: 0.721/0.562
# ['Chris Paul']
# k: 7, Train/Test Score: 0.726/0.601
# ['Clint Capela']
# k: 7, Train/Test Score: 0.723/0.597
# ['Cody Zeller']
# k: 7, Train/Test Score: 0.709/0.617
# ['Corey Brewer']
# k: 7, Train/Test Score: 0.670/0.573
# ['Cory Joseph']
# k: 7, Train/Test Score: 0.714/0.573
# ['Courtney Lee']
# k: 7, Train/Test Score: 0.680/0.591
# ['Cristiano Felicio']
# k: 7, Train/Test Score: 0.685/0.622
# ["D'Angelo Russell"]
# k: 7, Train/Test Score: 0.667/0.552
# ['D.J. Augustin']
# k: 7, Train/Test Score: 0.696/0.566
# ['Damian Lillard']
# k: 7, Train/Test Score: 0.759/0.636
# ['Daniel Theis']
# k: 7, Train/Test Score: 0.711/0.620
# ['Danilo Gallinari']
# k: 7, Train/Test Score: 0.763/0.616
# ['Danny Green']
# k: 7, Train/Test Score: 0.685/0.610
# ['Dante Cunningham']
# k: 7, Train/Test Score: 0.718/0.567
# ['Dario Saric']
# k: 7, Train/Test Score: 0.710/0.633
# ['Darius Miller']
# k: 7, Train/Test Score: 0.694/0.530
# ['Darren Collison']
# k: 7, Train/Test Score: 0.690/0.551
# ['David Nwaba']
# k: 7, Train/Test Score: 0.689/0.611
# ['David West']
# k: 7, Train/Test Score: 0.697/0.638
# ['Davis Bertans']
# k: 7, Train/Test Score: 0.715/0.486
# ["De'Aaron Fox"]
# k: 7, Train/Test Score: 0.704/0.625
# ['DeAndre Jordan']
# k: 7, Train/Test Score: 0.654/0.608
# ['DeMar DeRozan']
# k: 7, Train/Test Score: 0.728/0.644
# ['DeMarcus Cousins']
# k: 7, Train/Test Score: 0.691/0.600
# ['DeMarre Carroll']
# k: 7, Train/Test Score: 0.697/0.616
# ['Dejounte Murray']
# k: 7, Train/Test Score: 0.673/0.540
# ['Delon Wright']
# k: 7, Train/Test Score: 0.718/0.541
# ['Dennis Schroder']
# k: 7, Train/Test Score: 0.713/0.618
# ['Dennis Smith Jr.']
# k: 7, Train/Test Score: 0.715/0.602
# ['Denzel Valentine']
# k: 7, Train/Test Score: 0.677/0.596
# ['Derrick Favors']
# k: 7, Train/Test Score: 0.705/0.612
# ['Derrick Rose']
# k: 7, Train/Test Score: 0.694/0.662
# ['Devin Booker']
# k: 7, Train/Test Score: 0.726/0.676
# ['Devin Harris']
# k: 7, Train/Test Score: 0.718/0.622
# ['Dewayne Dedmon']
# k: 7, Train/Test Score: 0.678/0.610
# ['Deyonta Davis']
# k: 7, Train/Test Score: 0.751/0.556
# ['Dillon Brooks']
# k: 7, Train/Test Score: 0.698/0.587
# ['Dion Waiters']
# k: 7, Train/Test Score: 0.705/0.592
# ['Dirk Nowitzki']
# k: 7, Train/Test Score: 0.680/0.585
# ['Domantas Sabonis']
# k: 7, Train/Test Score: 0.722/0.628
# ['Donovan Mitchell']
# k: 7, Train/Test Score: 0.713/0.580
# ['Doug McDermott']
# k: 7, Train/Test Score: 0.680/0.588
# ['Dragan Bender']
# k: 7, Train/Test Score: 0.693/0.575
# ['Draymond Green']
# k: 7, Train/Test Score: 0.729/0.653
# ['Dwayne Bacon']
# k: 7, Train/Test Score: 0.718/0.600
# ['Dwight Buycks']
# k: 7, Train/Test Score: 0.709/0.550
# ['Dwight Howard']
# k: 7, Train/Test Score: 0.665/0.615
# ['Dwight Powell']
# k: 7, Train/Test Score: 0.738/0.643
# ['Dwyane Wade']
# k: 7, Train/Test Score: 0.708/0.580
# ["E'Twaun Moore"]
# k: 7, Train/Test Score: 0.688/0.618
# ['Ed Davis']
# k: 7, Train/Test Score: 0.702/0.571
# ['Elfrid Payton']
# k: 7, Train/Test Score: 0.674/0.522
# ['Emmanuel Mudiay']
# k: 7, Train/Test Score: 0.731/0.579
# ['Enes Kanter']
# k: 7, Train/Test Score: 0.716/0.674
# ['Eric Bledsoe']
# k: 7, Train/Test Score: 0.707/0.585
# ['Eric Gordon']
# k: 7, Train/Test Score: 0.701/0.646
# ['Ersan Ilyasova']
# k: 7, Train/Test Score: 0.721/0.582
# ['Evan Fournier']
# k: 7, Train/Test Score: 0.695/0.594
# ['Evan Turner']
# k: 7, Train/Test Score: 0.712/0.561
# ['Frank Kaminsky']
# k: 7, Train/Test Score: 0.716/0.627
# ['Frank Mason']
# k: 7, Train/Test Score: 0.710/0.605
# ['Frank Ntilikina']
# k: 7, Train/Test Score: 0.695/0.627
# ['Fred VanVleet']
# k: 7, Train/Test Score: 0.711/0.575
# ['Garrett Temple']
# k: 7, Train/Test Score: 0.679/0.568
# ['Gary Harris']
# k: 7, Train/Test Score: 0.712/0.593
# ['George Hill']
# k: 7, Train/Test Score: 0.707/0.584
# ['Gerald Green']
# k: 7, Train/Test Score: 0.686/0.569
# ['Giannis Antetokounmpo']
# k: 7, Train/Test Score: 0.749/0.640
# ['Goran Dragic']
# k: 7, Train/Test Score: 0.705/0.571
# ['Gorgui Dieng']
# k: 7, Train/Test Score: 0.656/0.672
# ['Greg Monroe']
# k: 7, Train/Test Score: 0.686/0.606
# ['Harrison Barnes']
# k: 7, Train/Test Score: 0.716/0.563
# ['Hassan Whiteside']
# k: 7, Train/Test Score: 0.719/0.553
# ['Ian Clark']
# k: 7, Train/Test Score: 0.675/0.583
# ['Ian Mahinmi']
# k: 7, Train/Test Score: 0.730/0.650
# ['Isaiah Taylor']
# k: 7, Train/Test Score: 0.681/0.662
# ['Isaiah Thomas']
# k: 7, Train/Test Score: 0.713/0.594
# ['Ish Smith']
# k: 7, Train/Test Score: 0.661/0.552
# ['J.J. Barea']
# k: 7, Train/Test Score: 0.704/0.566
# ['JJ Redick']
# k: 7, Train/Test Score: 0.722/0.571
# ['JR Smith']
# k: 7, Train/Test Score: 0.688/0.535
# ['JaMychal Green']
# k: 7, Train/Test Score: 0.699/0.580
# ['JaVale McGee']
# k: 7, Train/Test Score: 0.755/0.682
# ['Jabari Parker']
# k: 7, Train/Test Score: 0.670/0.586
# ['Jae Crowder']
# k: 7, Train/Test Score: 0.716/0.628
# ['Jakob Poeltl']
# k: 7, Train/Test Score: 0.716/0.634
# ['Jamal Crawford']
# k: 7, Train/Test Score: 0.687/0.616
# ['Jamal Murray']
# k: 7, Train/Test Score: 0.704/0.596
# ['Jameer Nelson']
# k: 7, Train/Test Score: 0.717/0.545
# ['James Ennis III']
# k: 7, Train/Test Score: 0.720/0.560
# ['James Harden']
# k: 7, Train/Test Score: 0.732/0.662
# ['James Johnson']
# k: 7, Train/Test Score: 0.679/0.587
# ['Jarell Martin']
# k: 7, Train/Test Score: 0.684/0.536
# ['Jarrett Allen']
# k: 7, Train/Test Score: 0.723/0.691
# ['Jarrett Jack']
# k: 7, Train/Test Score: 0.706/0.546
# ['Jawun Evans']
# k: 7, Train/Test Score: 0.689/0.487
# ['Jaylen Brown']
# k: 7, Train/Test Score: 0.676/0.559
# ['Jayson Tatum']
# k: 7, Train/Test Score: 0.713/0.636
# ['Jeff Green']
# k: 7, Train/Test Score: 0.733/0.658
# ['Jeff Teague']
# k: 7, Train/Test Score: 0.718/0.545
# ['Jerami Grant']
# k: 7, Train/Test Score: 0.665/0.629
# ['Jeremy Lamb']
# k: 7, Train/Test Score: 0.712/0.588
# ['Jerian Grant']
# k: 7, Train/Test Score: 0.680/0.555
# ['Jerryd Bayless']
# k: 7, Train/Test Score: 0.659/0.623
# ['Jimmy Butler']
# k: 7, Train/Test Score: 0.734/0.613
# ['Jodie Meeks']
# k: 7, Train/Test Score: 0.728/0.617
# ['Joe Harris']
# k: 7, Train/Test Score: 0.673/0.643
# ['Joe Ingles']
# k: 7, Train/Test Score: 0.645/0.528
# ['Joe Johnson']
# k: 7, Train/Test Score: 0.677/0.575
# ['Joe Young']
# k: 7, Train/Test Score: 0.702/0.574
# ['Joel Embiid']
# k: 7, Train/Test Score: 0.721/0.655
# ['Joffrey Lauvergne']
# k: 7, Train/Test Score: 0.674/0.617
# ['John Collins']
# k: 7, Train/Test Score: 0.712/0.628
# ['John Henson']
# k: 7, Train/Test Score: 0.701/0.580
# ['John Wall']
# k: 7, Train/Test Score: 0.704/0.563
# ['Jonas Jerebko']
# k: 7, Train/Test Score: 0.739/0.486
# ['Jonas Valanciunas']
# k: 7, Train/Test Score: 0.712/0.635
# ['Jonathon Simmons']
# k: 7, Train/Test Score: 0.686/0.582
# ['Jordan Bell']
# k: 7, Train/Test Score: 0.684/0.594
# ['Jordan Clarkson']
# k: 7, Train/Test Score: 0.706/0.588
# ['Jose Calderon']
# k: 7, Train/Test Score: 0.703/0.525
# ['Josh Hart']
# k: 7, Train/Test Score: 0.684/0.585
# ['Josh Huestis']
# k: 7, Train/Test Score: 0.773/0.538
# ['Josh Jackson']
# k: 7, Train/Test Score: 0.695/0.614
# ['Josh Richardson']
# k: 7, Train/Test Score: 0.692/0.576
# ['Jrue Holiday']
# k: 7, Train/Test Score: 0.711/0.613
# ['Julius Randle']
# k: 7, Train/Test Score: 0.748/0.714
# ['Justin Anderson']
# k: 7, Train/Test Score: 0.704/0.516
# ['Justin Holiday']
# k: 7, Train/Test Score: 0.718/0.574
# ['Justin Jackson']
# k: 7, Train/Test Score: 0.694/0.614
# ['Justise Winslow']
# k: 7, Train/Test Score: 0.651/0.558
# ['Jusuf Nurkic']
# k: 7, Train/Test Score: 0.689/0.524
# ['Karl-Anthony Towns']
# k: 7, Train/Test Score: 0.726/0.618
# ['Kelly Olynyk']
# k: 7, Train/Test Score: 0.715/0.658
# ['Kelly Oubre Jr.']
# k: 7, Train/Test Score: 0.718/0.652
# ['Kemba Walker']
# k: 7, Train/Test Score: 0.733/0.590
# ['Kent Bazemore']
# k: 7, Train/Test Score: 0.721/0.514
# ['Kentavious Caldwell-Pope']
# k: 7, Train/Test Score: 0.700/0.625
# ['Kevin Durant']
# k: 7, Train/Test Score: 0.738/0.649
# ['Kevin Love']
# k: 7, Train/Test Score: 0.735/0.636
# ['Kevon Looney']
# k: 7, Train/Test Score: 0.658/0.593
# ['Khris Middleton']
# k: 7, Train/Test Score: 0.739/0.574
# ['Klay Thompson']
# k: 7, Train/Test Score: 0.699/0.525
# ['Kobi Simmons']
# k: 7, Train/Test Score: 0.713/0.500
# ['Kosta Koufos']
# k: 7, Train/Test Score: 0.729/0.595
# ['Kris Dunn']
# k: 7, Train/Test Score: 0.687/0.556
# ['Kristaps Porzingis']
# k: 7, Train/Test Score: 0.687/0.601
# ['Kyle Anderson']
# k: 7, Train/Test Score: 0.711/0.566
# ['Kyle Korver']
# k: 7, Train/Test Score: 0.697/0.581
# ['Kyle Kuzma']
# k: 7, Train/Test Score: 0.682/0.654
# ['Kyle Lowry']
# k: 7, Train/Test Score: 0.719/0.602
# ["Kyle O'Quinn"]
# k: 7, Train/Test Score: 0.702/0.602
# ['Kyrie Irving']
# k: 7, Train/Test Score: 0.733/0.635
# ['LaMarcus Aldridge']
# k: 7, Train/Test Score: 0.730/0.666
# ['Lance Stephenson']
# k: 7, Train/Test Score: 0.673/0.588
# ['Lance Thomas']
# k: 7, Train/Test Score: 0.729/0.562
# ['Langston Galloway']
# k: 7, Train/Test Score: 0.740/0.594
# ['Larry Nance Jr.']
# k: 7, Train/Test Score: 0.742/0.602
# ['Lauri Markkanen']
# k: 7, Train/Test Score: 0.711/0.642
# ['LeBron James']
# k: 7, Train/Test Score: 0.725/0.655
# ['Lonzo Ball']
# k: 7, Train/Test Score: 0.710/0.585
# ['Lou Williams']
# k: 7, Train/Test Score: 0.743/0.670
# ['Luc Mbah a Moute']
# k: 7, Train/Test Score: 0.704/0.554
# ['Luke Babbitt']
# k: 7, Train/Test Score: 0.697/0.633
# ['Luke Kennard']
# k: 7, Train/Test Score: 0.696/0.559
# ['Malcolm Brogdon']
# k: 7, Train/Test Score: 0.699/0.567
# ['Malcolm Delaney']
# k: 7, Train/Test Score: 0.734/0.589
# ['Malik Beasley']
# k: 7, Train/Test Score: 0.690/0.396
# ['Malik Monk']
# k: 7, Train/Test Score: 0.683/0.629
# ['Manu Ginobili']
# k: 7, Train/Test Score: 0.715/0.640
# ['Marc Gasol']
# k: 7, Train/Test Score: 0.719/0.606
# ['Marcin Gortat']
# k: 7, Train/Test Score: 0.677/0.567
# ['Marco Belinelli']
# k: 7, Train/Test Score: 0.706/0.624
# ['Marcus Morris']
# k: 7, Train/Test Score: 0.698/0.504
# ['Marcus Smart']
# k: 7, Train/Test Score: 0.698/0.614
# ['Mario Chalmers']
# k: 7, Train/Test Score: 0.749/0.589
# ['Mario Hezonja']
# k: 7, Train/Test Score: 0.694/0.608
# ['Markieff Morris']
# k: 7, Train/Test Score: 0.653/0.562
# ['Marquese Chriss']
# k: 7, Train/Test Score: 0.708/0.654
# ['Marreese Speights']
# k: 7, Train/Test Score: 0.673/0.564
# ['Marvin Williams']
# k: 7, Train/Test Score: 0.708/0.605
# ['Mason Plumlee']
# k: 7, Train/Test Score: 0.706/0.584
# ['Maurice Harkless']
# k: 7, Train/Test Score: 0.692/0.613
# ['Maxi Kleber']
# k: 7, Train/Test Score: 0.678/0.652
# ['Michael Beasley']
# k: 7, Train/Test Score: 0.712/0.614
# ['Michael Carter-Williams']
# k: 7, Train/Test Score: 0.777/0.662
# ['Michael Kidd-Gilchrist']
# k: 7, Train/Test Score: 0.703/0.601
# ['Mike Conley']
# k: 7, Train/Test Score: 0.714/0.593
# ['Mike James']
# k: 7, Train/Test Score: 0.719/0.554
# ['Mike Muscala']
# k: 7, Train/Test Score: 0.698/0.628
# ['Mike Scott']
# k: 7, Train/Test Score: 0.699/0.549
# ['Miles Plumlee']
# k: 7, Train/Test Score: 0.722/0.533
# ['Milos Teodosic']
# k: 7, Train/Test Score: 0.691/0.667
# ['Montrezl Harrell']
# k: 7, Train/Test Score: 0.714/0.580
# ['Myles Turner']
# k: 7, Train/Test Score: 0.711/0.587
# ['Nemanja Bjelica']
# k: 7, Train/Test Score: 0.680/0.509
# ['Nene']
# k: 7, Train/Test Score: 0.667/0.516
# ['Nick Young']
# k: 7, Train/Test Score: 0.728/0.656
# ['Nicolas Batum']
# k: 7, Train/Test Score: 0.718/0.579
# ['Nikola Jokic']
# k: 7, Train/Test Score: 0.723/0.559
# ['Nikola Mirotic']
# k: 7, Train/Test Score: 0.698/0.604
# ['Nikola Vucevic']
# k: 7, Train/Test Score: 0.707/0.585
# ['Noah Vonleh']
# k: 7, Train/Test Score: 0.680/0.507
# ['Norman Powell']
# k: 7, Train/Test Score: 0.740/0.648
# ['OG Anunoby']
# k: 7, Train/Test Score: 0.697/0.576
# ['Omri Casspi']
# k: 7, Train/Test Score: 0.705/0.580
# ['Otto Porter Jr.']
# k: 7, Train/Test Score: 0.678/0.564
# ['PJ Tucker']
# k: 7, Train/Test Score: 0.687/0.573
# ['Pascal Siakam']
# k: 7, Train/Test Score: 0.743/0.634
# ['Pat Connaughton']
# k: 7, Train/Test Score: 0.663/0.566
# ['Patrick McCaw']
# k: 7, Train/Test Score: 0.747/0.652
# ['Patrick Patterson']
# k: 7, Train/Test Score: 0.722/0.625
# ['Patty Mills']
# k: 7, Train/Test Score: 0.696/0.634
# ['Pau Gasol']
# k: 7, Train/Test Score: 0.696/0.613
# ['Paul George']
# k: 7, Train/Test Score: 0.731/0.602
# ['Paul Millsap']
# k: 7, Train/Test Score: 0.682/0.573
# ['Paul Zipser']
# k: 7, Train/Test Score: 0.728/0.462
# ['Quincy Acy']
# k: 7, Train/Test Score: 0.689/0.617
# ['Quinn Cook']
# k: 7, Train/Test Score: 0.733/0.560
# ['Rajon Rondo']
# k: 7, Train/Test Score: 0.676/0.611
# ['Raul Neto']
# k: 7, Train/Test Score: 0.681/0.537
# ['Raymond Felton']
# k: 7, Train/Test Score: 0.707/0.506
# ['Reggie Bullock']
# k: 7, Train/Test Score: 0.652/0.544
# ['Reggie Jackson']
# k: 7, Train/Test Score: 0.709/0.590
# ['Richaun Holmes']
# k: 7, Train/Test Score: 0.741/0.587
# ['Ricky Rubio']
# k: 7, Train/Test Score: 0.711/0.578
# ['Robert Covington']
# k: 7, Train/Test Score: 0.700/0.592
# ['Robin Lopez']
# k: 7, Train/Test Score: 0.677/0.609
# ['Rodney Hood']
# k: 7, Train/Test Score: 0.702/0.604
# ['Rondae Hollis-Jefferson']
# k: 7, Train/Test Score: 0.712/0.627
# ["Royce O'Neale"]
# k: 7, Train/Test Score: 0.724/0.642
# ['Rudy Gay']
# k: 7, Train/Test Score: 0.700/0.646
# ['Rudy Gobert']
# k: 7, Train/Test Score: 0.709/0.688
# ['Russell Westbrook']
# k: 7, Train/Test Score: 0.706/0.624
# ['Ryan Anderson']
# k: 7, Train/Test Score: 0.700/0.530
# ['Salah Mejri']
# k: 7, Train/Test Score: 0.684/0.510
# ['Sam Dekker']
# k: 7, Train/Test Score: 0.720/0.722
# ['Sean Kilpatrick']
# k: 7, Train/Test Score: 0.711/0.576
# ['Semi Ojeleye']
# k: 7, Train/Test Score: 0.756/0.456
# ['Serge Ibaka']
# k: 7, Train/Test Score: 0.701/0.594
# ['Shabazz Muhammad']
# k: 7, Train/Test Score: 0.690/0.576
# ['Shabazz Napier']
# k: 7, Train/Test Score: 0.697/0.602
# ['Shane Larkin']
# k: 7, Train/Test Score: 0.667/0.703
# ['Shaun Livingston']
# k: 7, Train/Test Score: 0.691/0.696
# ['Shelvin Mack']
# k: 7, Train/Test Score: 0.692/0.633
# ['Sindarius Thornwell']
# k: 7, Train/Test Score: 0.692/0.506
# ['Skal Labissiere']
# k: 7, Train/Test Score: 0.738/0.535
# ['Spencer Dinwiddie']
# k: 7, Train/Test Score: 0.732/0.625
# ['Stanley Johnson']
# k: 7, Train/Test Score: 0.737/0.588
# ['Stephen Curry']
# k: 7, Train/Test Score: 0.746/0.676
# ['Sterling Brown']
# k: 7, Train/Test Score: 0.680/0.627
# ['Steven Adams']
# k: 7, Train/Test Score: 0.682/0.600
# ['T.J. McConnell']
# k: 7, Train/Test Score: 0.729/0.468
# ['TJ Warren']
# k: 7, Train/Test Score: 0.702/0.639
# ['Taj Gibson']
# k: 7, Train/Test Score: 0.734/0.679
# ['Taurean Prince']
# k: 7, Train/Test Score: 0.719/0.612
# ['Terrence Ross']
# k: 7, Train/Test Score: 0.706/0.544
# ['Terry Rozier']
# k: 7, Train/Test Score: 0.704/0.557
# ['Thabo Sefolosha']
# k: 7, Train/Test Score: 0.695/0.676
# ['Thaddeus Young']
# k: 7, Train/Test Score: 0.709/0.531
# ['Thon Maker']
# k: 7, Train/Test Score: 0.694/0.631
# ['Tim Frazier']
# k: 7, Train/Test Score: 0.717/0.588
# ['Tim Hardaway Jr.']
# k: 7, Train/Test Score: 0.728/0.614
# ['Timothe Luwawu-Cabarrot']
# k: 7, Train/Test Score: 0.700/0.573
# ['Tobias Harris']
# k: 7, Train/Test Score: 0.701/0.519
# ['Tomas Satoransky']
# k: 7, Train/Test Score: 0.675/0.584
# ['Tony Parker']
# k: 7, Train/Test Score: 0.686/0.578
# ['Tony Snell']
# k: 7, Train/Test Score: 0.667/0.552
# ['Treveon Graham']
# k: 7, Train/Test Score: 0.729/0.629
# ['Trevor Ariza']
# k: 7, Train/Test Score: 0.723/0.583
# ['Trevor Booker']
# k: 7, Train/Test Score: 0.714/0.614
# ['Trey Burke']
# k: 7, Train/Test Score: 0.639/0.486
# ['Trey Lyles']
# k: 7, Train/Test Score: 0.695/0.592
# ['Tristan Thompson']
# k: 7, Train/Test Score: 0.686/0.495
# ['Troy Daniels']
# k: 7, Train/Test Score: 0.704/0.562
# ['Tyler Dorsey']
# k: 7, Train/Test Score: 0.713/0.598
# ['Tyler Ennis']
# k: 7, Train/Test Score: 0.646/0.531
# ['Tyler Johnson']
# k: 7, Train/Test Score: 0.711/0.543
# ['Tyler Ulis']
# k: 7, Train/Test Score: 0.716/0.620
# ['Tyler Zeller']
# k: 7, Train/Test Score: 0.693/0.604
# ['Tyreke Evans']
# k: 7, Train/Test Score: 0.700/0.541
# ['Tyrone Wallace']
# k: 7, Train/Test Score: 0.708/0.732
# ['Tyson Chandler']
# k: 7, Train/Test Score: 0.743/0.592
# ['Tyus Jones']
# k: 7, Train/Test Score: 0.731/0.625
# ['Victor Oladipo']
# k: 7, Train/Test Score: 0.717/0.569
# ['Vince Carter']
# k: 7, Train/Test Score: 0.646/0.617
# ['Wayne Ellington']
# k: 7, Train/Test Score: 0.717/0.510
# ['Wayne Selden']
# k: 7, Train/Test Score: 0.720/0.634
# ['Wes Iwundu']
# k: 7, Train/Test Score: 0.712/0.642
# ['Wesley Johnson']
# k: 7, Train/Test Score: 0.712/0.645
# ['Wesley Matthews']
# k: 7, Train/Test Score: 0.702/0.605
# ['Will Barton']
# k: 7, Train/Test Score: 0.722/0.573
# ['Willie Cauley-Stein']
# k: 7, Train/Test Score: 0.717/0.573
# ['Willy Hernangomez']
# k: 7, Train/Test Score: 0.723/0.656
# ['Wilson Chandler']
# k: 7, Train/Test Score: 0.696/0.647
# ['Yogi Ferrell']
# k: 7, Train/Test Score: 0.683/0.598
# ['Zach Collins']
# k: 7, Train/Test Score: 0.704/0.620
# ['Zach LaVine']
# k: 7, Train/Test Score: 0.725/0.560
# ['Zach Randolph']
# k: 7, Train/Test Score: 0.702/0.555
# ['Zaza Pachulia']
# k: 7, Train/Test Score: 0.690/0.691

# %%
from sklearn.model_selection import train_test_split

#y = pd.get_dummies(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-98188b8a9594> in <module>()
#       3 #y = pd.get_dummies(y)
#       4
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#
# NameError: name 'X' is not defined

# %%
y_trainArray = np.array(y_train).reshape(-1,1)

# %%
from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_trainArray)
# Out:
# C:\Users\pablo\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
train_scores = []
test_scores = []


knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_scaled, y_trainArray)
train_score = knn.score(X_train_scaled, y_trainArray)
test_score = knn.score(X_test_scaled, y_test)
train_scores.append(train_score)
test_scores.append(test_score)
print(f"k: {7}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
# Out:
# k: 7, Train/Test Score: 0.732/0.662
# C:\Users\pablo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
