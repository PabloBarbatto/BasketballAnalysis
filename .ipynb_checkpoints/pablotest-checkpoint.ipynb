# %%
import pandas as pd
import numpy as np
import os
import csv

data_df = pd.read_csv('combined_stats.csv', low_memory=False)

# %%
data_df.columns
# Out:
# Index(['game_id', 'data_set', 'date', 'a1', 'a2', 'a3', 'a4', 'a5', 'h1', 'h2',
#        'h3', 'h4', 'h5', 'period', 'away_score', 'home_score',
#        'remaining_time', 'elapsed', 'play_length', 'play_id', 'team',
#        'event_type', 'assist', 'away', 'home', 'block', 'entered', 'left',
#        'num', 'opponent', 'outof', 'player', 'player_uid', 'points',
#        'possession', 'reason', 'result', 'steal', 'type', 'shot_distance',
#        'original_x', 'original_y', 'converted_x', 'converted_y',
#        'description'],
#       dtype='object')

# %%
data_df = data_df.drop(columns=['description',"data_set","date","away_score","home_score","remaining_time","elapsed","play_length",
                               'play_id',"event_type","assist","away","home","block","entered","left","num","opponent","outof",
                               'possession',"reason",'steal',"game_id"])

# %%
data_df = data_df.dropna(subset=['result'])

# %%
data_df.head(10)
data_df["shot counter"] = 0
data_df.head(10)
# Out:
#                 a1            a2          a3            a4            a5  \
# 2   Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 3   Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 5   Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 7   Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 9   Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 11  Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 13  Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 14  Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 17  Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
# 18  Gordon Hayward  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving
#
#               h1           h2          h3           h4            h5  \
# 2   LeBron James  Jae Crowder  Kevin Love  Dwyane Wade  Derrick Rose
# ...

# %%
players = []
shot_counts = []
for row in data_df.iterrows():
    
    if data_df['player'] in players:
        data_df["shot counter"] = data_df["shot counter"] + 1
        
    else:
        players.append(data_df['player'])
        data_df["shot counter"] = 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-21a51efd92fa> in <module>()
#       3 for row in data_df.iterrows():
#       4
# ----> 5     if data_df['player'] in players:
#       6         data_df["shot counter"] = data_df["shot counter"] + 1
#       7
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
max_shots = shot_counts[0]
max_index = 0
for count in range(len(players)):
    if shot_counts[count] > max_shots:
        max_shots = shot_counts[count]
        print(max_shots)
        max_index = count
winner = players[max_index]

# %%
for count in range(len(players)):
    print(players[count],shot_counts[count])
print(winner)
# Out:
# 2           Kyrie Irving
# 3           Derrick Rose
# 5         Gordon Hayward
# 7             Kevin Love
# 9           Jayson Tatum
# 11            Al Horford
# 13            Kevin Love
# 14           Jae Crowder
# 17           Dwyane Wade
# 18          Jaylen Brown
# 20          Derrick Rose
# 22        Gordon Hayward
# 23          Derrick Rose
# 26           Jae Crowder
# 27           Jae Crowder
# 28          Kyrie Irving
# 30           Dwyane Wade
# 32          Kyrie Irving
# 34          Jaylen Brown
# 35           Jae Crowder
# 40            Al Horford
# 42          Jaylen Brown
# 46          Jaylen Brown
# 48          LeBron James
# 52          Derrick Rose
# 54          Marcus Smart
# 56          LeBron James
# 57          Kyrie Irving
# 58          Derrick Rose
# 59          Kyrie Irving
#                ...
# 599323       Rodney Hood
# 599326     Stephen Curry
# 599328       Kyle Korver
# 599330     Stephen Curry
# 599332      LeBron James
# 599333     Stephen Curry
# ...

# %%
for row in df.iterrows():
    candidate = line[2]
    if candidate in candidates:
        candidate_index = candidates.index(candidate)
        vote_counts[candidate_index] = vote_counts[candidate_index] + 1
    else:
        candidates.append(candidate)
        vote_counts.append(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8afa6bdd8478> in <module>()
# ----> 1 for row in df.iterrows():
#       2     candidate = line[2]
#       3     if candidate in candidates:
#       4         candidate_index = candidates.index(candidate)
#       5         vote_counts[candidate_index] = vote_counts[candidate_index] + 1
#
# NameError: name 'df' is not defined

# %%
percentages = []
max_votes = vote_counts[0]
max_index = 0
for count in range(len(candidates)):
    vote_percentage = round((vote_counts[count]/num_votes*100),3)
    percentages.append(vote_percentage)
    if vote_counts[count] > max_votes:
        max_votes = vote_counts[count]
        print(max_votes)
        max_index = count
winner = candidates[max_index]
